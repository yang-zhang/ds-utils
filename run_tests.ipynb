# %%
# %matplotlib inline
# %run ds_utils/visualization.py
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):
# .
# ----------------------------------------------------------------------
# Ran 1 test in 5.136s
#
# OK

# %%
import ds_utils.stats
ds_utils.stats.TestStatsMethods().test_df_corrcoef_matrix()
# Out:
#     date_signed_on has_churned      income price_plan product_purchased  \
# 874     2012-01-29        True  503.951140          A                 Y
# 182     2010-03-19        True  502.669041          A                 Z
# 461     2013-10-19       False  500.537341          B                 Y
# 191     2013-06-11       False         NaN          A                 Z
# 185     2016-06-09       False  504.944131          A                 Z
#
#     region        tax  total_purchase  user_id
# 874      c  51.840760             116    874.0
# 182      c  51.302729             111    182.0
# 461      b  50.817784             117    461.0
# 191      d  51.837924             108    191.0
# 185      c  50.539834             101    185.0
#                 total_purchase    income       tax
# total_purchase        1.000000  0.001239 -0.058900
# income                0.001239  1.000000 -0.034975
# tax                  -0.058900 -0.034975  1.000000
